# %%
import pandas as pd
import pandas_profiling
import numpy as np
import json
from pymystem3 import Mystem
from urllib.request import urlopen
from pandas.io.json import json_normalize
import collections
import ast
import time

# %%
import urllib.request
req = urllib.request.Request('http://api.thequestion.ru/api/topics')
response = urllib.request.urlopen(req)
result = json.loads(response.read().decode('utf-8'))

# %%
result
# Out:
# [{'id': 18755,
#   'title': ':(',
#   'color': 'd88b60',
#   'createdAt': '2017-06-28T03:10:20Z',
#   'updatedAt': '2017-06-28T03:10:20Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 2,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18755/0f1070fbd2a4b1253222bb7a18dff177cc667bca?t=1498619420',
#   'followed': False,
#   'isExpert': False},
#  {'id': 16768,
#   'title': ':)',
#   'color': '659ef3',
#   'createdAt': '2017-04-26T18:12:07Z',
#   'updatedAt': '2017-04-26T18:12:07Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 15,
#   'totalFollowers': 18,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/16768/50bf53f30146f954895cb99444099d3baf4f9d7c?t=1493230327',
#   'followed': False,
#   'isExpert': False},
#  {'id': 19801,
#   'title': ':))',
#   'color': 'a69d7f',
#   'createdAt': '2017-08-03T05:34:26Z',
#   'updatedAt': '2017-08-03T05:34:26Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 3,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/19801/cef8aff1064e027e5530e74171e04fa993871373?t=1501738466',
#   'followed': False,
#   'isExpert': False},
#  {'id': 1624,
#   'title': '?',
#   'color': '00b3a5',
#   'createdAt': '2016-01-19T15:56:19Z',
#   'updatedAt': '2016-01-19T15:56:19Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 221,
#   'totalFollowers': 827,
#   'totalQuestions': 36,
#   'totalAnsweredQuestions': 15,
#   'totalUnansweredQuestions': 21,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/1624/d3fc4dd2b75840403b0691ff30e23e6f9311ca33?t=1453218979',
#   'followed': False,
#   'isExpert': False},
#  {'id': 5807,
#   'title': '???',
#   'color': '00b19c',
#   'createdAt': '2016-05-26T20:28:56Z',
#   'updatedAt': '2016-05-26T20:28:56Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 34,
#   'totalFollowers': 99,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 3,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/5807/cc28ccc37f4f3ff941a8e3c7a766cdf6f1a92a68?t=1464294536',
#   'followed': False,
#   'isExpert': False},
#  {'id': 12246,
#   'title': '.',
#   'color': '94a46c',
#   'createdAt': '2016-12-14T16:40:08Z',
#   'updatedAt': '2016-12-14T16:40:08Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 12,
#   'totalFollowers': 13,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/12246/0a60b19cfe81732c3bf60dd2ef5332d6daf90d11?t=1481733608',
#   'followed': False,
#   'isExpert': False},
#  {'id': 14571,
#   'title': '...',
#   'color': 'b68ed1',
#   'createdAt': '2017-02-18T15:24:35Z',
#   'updatedAt': '2017-02-18T15:24:35Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 7,
#   'totalFollowers': 5,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 2,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/14571/caa7b2d81abc86681de25cc166d4de7481b810bb?t=1487431475',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18941,
#   'title': '(???)',
#   'color': 'c79268',
#   'createdAt': '2017-07-04T13:56:22Z',
#   'updatedAt': '2017-07-04T13:56:22Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 1,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18941/8918e8c3ec67491b75878f451e3ef574898d9dd1?t=1499176582',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18019,
#   'title': '******',
#   'color': '00b1be',
#   'createdAt': '2017-06-05T09:44:31Z',
#   'updatedAt': '2017-06-05T09:44:31Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 1,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18019/841a305e7aa7a366bd809aa56463d8be17024342?t=1496655871',
#   'followed': False,
#   'isExpert': False},
#  {'id': 33923,
#   'title': '###',
#   'color': '37aea3',
#   'createdAt': '2019-03-27T19:43:58Z',
#   'updatedAt': '2019-03-27T19:43:58Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/33923/5292f508db293aaf3d4e5339c242dea2c0dd23ca?t=1553715838',
#   'followed': False,
#   'isExpert': False},
#  {'id': 32860,
#   'title': '%',
#   'color': '70aa80',
#   'createdAt': '2019-02-06T18:38:53Z',
#   'updatedAt': '2019-02-06T18:38:53Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/32860/a32524dea8febf5630b1d0d79cb574e00adc87d5?t=1549478333',
#   'followed': False,
#   'isExpert': False},
#  {'id': 9872,
#   'title': '+',
#   'color': 'b2979c',
#   'createdAt': '2016-10-08T18:12:28Z',
#   'updatedAt': '2016-10-08T18:12:28Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 7,
#   'totalFollowers': 18,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 2,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/9872/7953e76d846796e445495a22402e5518db457f0e?t=1475950348',
#   'followed': False,
#   'isExpert': False},
#  {'id': 19582,
#   'title': '\u200d \u200d \u200d \u200d \u200d \u200d \u200d',
#   'color': '00b1e9',
#   'createdAt': '2017-07-27T13:34:16Z',
#   'updatedAt': '2017-07-27T13:34:16Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/19582/9e4d0c9e298b395befcc8161598b46d0baa3e63c?t=1501162456',
#   'followed': False,
#   'isExpert': False},
#  {'id': 19583,
#   'title': '\u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d',
#   'color': '00b393',
#   'createdAt': '2017-07-27T13:34:17Z',
#   'updatedAt': '2017-07-27T13:34:17Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/19583/2b9aee6b2904391eb6bef0c31abacf038022c4e0?t=1501162457',
#   'followed': False,
#   'isExpert': False},
#  {'id': 19584,
#   'title': '\u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d \u200d',
#   'color': 'cf8a9c',
#   'createdAt': '2017-07-27T13:34:17Z',
#   'updatedAt': '2017-07-27T13:34:17Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/19584/6799e9724f2e074140d628375072b9d361aab983?t=1501162457',
#   'followed': False,
#   'isExpert': False},
#  {'id': 23888,
#   'title': 'イリヤ アン',
#   'color': 'a49aaa',
#   'createdAt': '2018-01-02T22:23:58Z',
#   'updatedAt': '2018-01-02T22:23:58Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/23888/292c580fa336db6e684aabc875ec80fef9535a7a?t=1514931838',
#   'followed': False,
#   'isExpert': False},
#  {'id': 31426,
#   'title': 'ＴＲＡＳＨ',
#   'color': 'be9843',
#   'createdAt': '2018-12-17T00:45:45Z',
#   'updatedAt': '2018-12-17T00:45:45Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/31426/208d55d3bc97aedaeee5e2c281c2b6db8770dc83?t=1545007545',
#   'followed': False,
#   'isExpert': False},
#  {'id': 5494,
#   'title': '007',
#   'color': '00aff1',
#   'createdAt': '2016-05-18T08:31:08Z',
#   'updatedAt': '2016-05-18T08:31:08Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 15,
#   'totalFollowers': 57,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 3,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/5494/4f3d4ea9220e2f8c4fa94d4b31f8ce8c52b7ed34?t=1463560268',
#   'followed': False,
#   'isExpert': False},
#  {'id': 30628,
#   'title': '00-е',
#   'color': '00b3bc',
#   'createdAt': '2018-11-20T14:19:53Z',
#   'updatedAt': '2018-11-20T14:19:53Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/30628/c7cbe9abc85b3ac8b3c2a52e2e4fcfe9f7c2b7f9?t=1542723593',
#   'followed': False,
#   'isExpert': False},
#  {'id': 11817,
#   'title': '01',
#   'color': '00b3d7',
#   'createdAt': '2016-12-03T10:58:28Z',
#   'updatedAt': '2016-12-03T10:58:28Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 4,
#   'totalFollowers': 8,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/11817/1afee3ae3df8b3241eae189935d1261779d97217?t=1480762708',
#   'followed': False,
#   'isExpert': False},
#  {'id': 34548,
#   'title': '0xc000007b',
#   'color': 'ed7f48',
#   'createdAt': '2019-05-14T15:03:29Z',
#   'updatedAt': '2019-05-14T15:03:29Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/34548/910b6e9d0b5ec65c10ea33c33ab925ee010c80ac?t=1557846209',
#   'followed': False,
#   'isExpert': False},
#  {'id': 9879,
#   'title': '1',
#   'color': 'f07d54',
#   'createdAt': '2016-10-08T18:54:33Z',
#   'updatedAt': '2016-10-08T18:54:33Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 3,
#   'totalFollowers': 14,
#   'totalQuestions': 7,
#   'totalAnsweredQuestions': 2,
#   'totalUnansweredQuestions': 5,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/9879/f618f4c3dfacce1c4b65db293863998bf896300c?t=1475952873',
#   'followed': False,
#   'isExpert': False},
#  {'id': 14215,
#   'title': '10',
#   'color': 'de8489',
#   'createdAt': '2017-02-09T20:59:08Z',
#   'updatedAt': '2017-02-09T20:59:08Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 2,
#   'totalFollowers': 2,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/14215/e3eac2892f742e379eb0effb6a61bd68f1207eb0?t=1486673948',
#   'followed': False,
#   'isExpert': False},
#  {'id': 24527,
#   'title': '+100500',
#   'color': 'a899a6',
#   'createdAt': '2018-01-30T14:57:03Z',
#   'updatedAt': '2018-01-30T14:57:03Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 2,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/24527/b5dea7e9fcc8818a0a89f1d5f376d8e3441d768e?t=1517324223',
#   'followed': False,
#   'isExpert': False},
#  {'id': 8981,
#   'title': '100БАЛЛОВ',
#   'color': '00afd2',
#   'createdAt': '2016-09-08T23:53:16Z',
#   'updatedAt': '2016-09-08T23:53:16Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 15,
#   'totalFollowers': 98,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/8981/b76b58b091ce7c2ba34f7da37f076bb7e9e368e3?t=1473378796',
#   'followed': False,
#   'isExpert': False},
#  {'id': 21909,
#   'title': '100 дней',
#   'color': 'ca934a',
#   'createdAt': '2017-10-17T18:29:44Z',
#   'updatedAt': '2017-10-17T18:29:44Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/21909/7a3aa46c14dfaa7926bad643946f03cea1b44e59?t=1508264984',
#   'followed': False,
#   'isExpert': False},
#  {'id': 8584,
#   'title': '10-11класс',
#   'color': '6fa2cf',
#   'createdAt': '2016-08-24T17:22:22Z',
#   'updatedAt': '2016-08-24T17:22:22Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 49,
#   'totalFollowers': 204,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/8584/6975352af7da620f751819dd70176166def5ad22?t=1472059342',
#   'followed': False,
#   'isExpert': False},
#  {'id': 30280,
#   'title': '1080',
#   'color': 'ea7f6d',
#   'createdAt': '2018-11-06T12:39:54Z',
#   'updatedAt': '2018-11-06T12:39:54Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/30280/6d77dbf4095889ad40505359ee72329fcd04f0ab?t=1541507994',
#   'followed': False,
#   'isExpert': False},
#  {'id': 30405,
#   'title': '1080p',
#   'color': 'bc8bd5',
#   'createdAt': '2018-11-11T11:05:54Z',
#   'updatedAt': '2018-11-11T11:05:54Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/30405/c0681f9ca4ae340e6183ee6f88202d48808e3a16?t=1541934354',
#   'followed': False,
#   'isExpert': False},
#  {'id': 23398,
#   'title': '10 альбомов',
#   'color': 'b38ce0',
#   'createdAt': '2017-12-13T19:29:01Z',
#   'updatedAt': '2017-12-13T19:29:01Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 1,
#   'totalQuestions': 12,
#   'totalAnsweredQuestions': 10,
#   'totalUnansweredQuestions': 2,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/23398/77468f86bf7b787c7ee340311579b30f373654fe?t=1513193341',
#   'followed': False,
#   'isExpert': False},
#  {'id': 27274,
#   'title': '10 вертолетных пулеметов',
#   'color': '00b2ce',
#   'createdAt': '2018-06-10T00:30:14Z',
#   'updatedAt': '2018-06-10T00:30:14Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/27274/c0ceb04e04f7a43effbbeb0d6bd5eaf955d4f8a3?t=1528590614',
#   'followed': False,
#   'isExpert': False},
#  {'id': 27288,
#   'title': '10 клас',
#   'color': '2bacc0',
#   'createdAt': '2018-06-10T17:36:09Z',
#   'updatedAt': '2018-06-10T17:36:09Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/27288/9d5160fec6bb4edf512d1ed99ce4dd0b55b9aa31?t=1528652169',
#   'followed': False,
#   'isExpert': False},
#  {'id': 5112,
#   'title': '10 класс',
#   'color': '9f9ab8',
#   'createdAt': '2016-05-06T10:53:05Z',
#   'updatedAt': '2016-05-06T10:53:05Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 44,
#   'totalFollowers': 169,
#   'totalQuestions': 21,
#   'totalAnsweredQuestions': 12,
#   'totalUnansweredQuestions': 9,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/5112/21708f7f86db15c0feaf3760ab64e49c70dc3c38?t=1462531985',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18404,
#   'title': '10 ПРИЧИН МОЕЙ НЕНАВИСТИ',
#   'color': '6da5c0',
#   'createdAt': '2017-06-17T12:11:49Z',
#   'updatedAt': '2017-06-17T12:11:49Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18404/6760b2c16cfa28c53fb706e40a0e237df14539d2?t=1497701509',
#   'followed': False,
#   'isExpert': False},
#  {'id': 7885,
#   'title': '1+1',
#   'color': 'bc8dc3',
#   'createdAt': '2016-07-31T09:03:53Z',
#   'updatedAt': '2016-07-31T09:03:53Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 14,
#   'totalFollowers': 62,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/7885/3e77ba3c4b9313846ff86df658d9b8c83f492453?t=1469955833',
#   'followed': False,
#   'isExpert': False},
#  {'id': 28909,
#   'title': '112',
#   'color': 'd088a2',
#   'createdAt': '2018-09-04T10:51:51Z',
#   'updatedAt': '2018-09-04T10:51:51Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/28909/e2936e537da7543eb35f9016234bd61f29f8a038?t=1536058311',
#   'followed': False,
#   'isExpert': False},
#  {'id': 22103,
#   'title': '#11 класс',
#   'color': 'cd8f73',
#   'createdAt': '2017-10-23T13:54:53Z',
#   'updatedAt': '2017-10-23T13:54:53Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/22103/f128a6a6170639ac81acdc8cb03f59281fe67273?t=1508766893',
#   'followed': False,
#   'isExpert': False},
#  {'id': 11201,
#   'title': '11 КЛАСС',
#   'color': '5baaa4',
#   'createdAt': '2016-11-18T17:45:20Z',
#   'updatedAt': '2016-11-18T17:45:20Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 16,
#   'totalFollowers': 64,
#   'totalQuestions': 23,
#   'totalAnsweredQuestions': 12,
#   'totalUnansweredQuestions': 11,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/11201/361483b670c53da4a63fd6a1868f7ff7ad5bbda8?t=1479491120',
#   'followed': False,
#   'isExpert': False},
#  {'id': 6155,
#   'title': '11 сентября',
#   'color': 'c09291',
#   'createdAt': '2016-06-03T14:17:52Z',
#   'updatedAt': '2017-09-11T07:49:44Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 13,
#   'totalFollowers': 158,
#   'totalQuestions': 8,
#   'totalAnsweredQuestions': 6,
#   'totalUnansweredQuestions': 2,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/6155/e3600c3655bdfc9673f336bc49d2bb0dc82569bc?t=1505116184',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18198,
#   'title': '120fps',
#   'color': 'af9a7d',
#   'createdAt': '2017-06-11T07:55:58Z',
#   'updatedAt': '2017-06-11T07:55:58Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18198/257698e9760a5821baeeb95a227a5dc3c18cc2fc?t=1497167758',
#   'followed': False,
#   'isExpert': False},
#  {'id': 8360,
#   'title': '122grinlibrary',
#   'color': '58a4df',
#   'companyId': 168,
#   'createdAt': '2016-08-17T06:33:10Z',
#   'updatedAt': '2016-08-17T06:33:10Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 6,
#   'totalFollowers': 18,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'company': {'id': 168,
#    'topicId': 8360,
#    'active': True,
#    'description': 'Библиотека №122 им. А.Грина',
#    'logoId': 237356,
#    'coverId': 238708,
#    'aboutQml': '<p>Библиотека № 122 им. Александра Грина находится в старейшем районе Москвы Лефортово в двухэтажном здании по адресу: ул. Волочаевская, д. 14А. Библиотека - старейшая библиотека Москвы, открытая в мае 1960 года для молодежи. </p><p>Сегодня она обладает самым большим фондов среди всех библиотек ЮВАО, в ее помещении на площади 1100 кв.м.: фонд библиотеки составляет сейчас более 110.000 книг и электронных изданий. </p><p>Наша библиотека помимо обычных отделов имеет отдел искусства, отделение для детей, компьютерный класс. </p><p>В настоящий момент Библиотека им. А. Грина как и все библиотеки Москвы преобразуется в библиотеку-культурный центр. Ежедневно проходит множество собственных мероприятий и мероприятий партнёров библиотеки.</p>',
#    'totalAccounts': 2,
#    'createdAt': '2016-08-17T06:33:31Z',
#    'updatedAt': '2016-08-17T06:33:31Z',
#    'activatedAt': '2016-08-17T06:33:31Z',
#    'title': '122grinlibrary',
#    'logo': {'id': 237356,
#     'accountId': 212,
#     'url': 'https://thequestion.s3.eu-central-1.amazonaws.com/212/237355-da557221.jpeg',
#     'size': 723046,
#     'createdAt': '2016-08-17T09:20:09Z',
#     'imageUrl': 'https://media.thequestion.ru/image/1280x640/0bceaf19ff63a2874a3d0769cc9d9b86e3debeec?url=https%3A%2F%2Fthequestion.s3.eu-central-1.amazonaws.com%2F212%2F237355-da557221.jpeg',
#     'thumbnailUrl': 'https://media.thequestion.ru/image/250x250/f9a328db5d2c39c9b04bda257979e7a7b2dd731c?url=https%3A%2F%2Fthequestion.s3.eu-central-1.amazonaws.com%2F212%2F237355-da557221.jpeg',
#     'width': 2312,
#     'height': 1945},
#    'cover': {'id': 238708,
#     'accountId': 2535,
#     'url': 'https://thequestion.s3.eu-central-1.amazonaws.com/535/238707-5d204436.jpeg',
#     'size': 2166219,
#     'createdAt': '2016-08-19T07:09:06Z',
#     'imageUrl': 'https://media.thequestion.ru/image/1280x640/fdf07709e13a1ee7ea83151f9afb101482769d03?url=https%3A%2F%2Fthequestion.s3.eu-central-1.amazonaws.com%2F535%2F238707-5d204436.jpeg',
#     'thumbnailUrl': 'https://media.thequestion.ru/image/250x250/1f398acf6f61365fee075cbc09e13587b11719a1?url=https%3A%2F%2Fthequestion.s3.eu-central-1.amazonaws.com%2F535%2F238707-5d204436.jpeg',
#     'width': 2560,
#     'height': 1600},
#    'permission': {'member': False, 'admin': False}},
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/8360/dbf8639fe03850712c0bc4788793dddf92e79a98?t=1471415590',
#   'followed': False,
#   'isExpert': False},
#  {'id': 6256,
#   'title': '123',
#   'color': '3ea6e1',
#   'createdAt': '2016-06-06T06:34:39Z',
#   'updatedAt': '2016-06-06T06:34:39Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 4,
#   'totalFollowers': 25,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/6256/09f5bff00d5ba4246586c8a177cdcaeae343b0ae?t=1465194879',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18186,
#   'title': '12июня',
#   'color': '9f92e9',
#   'createdAt': '2017-06-10T15:06:35Z',
#   'updatedAt': '2017-06-10T15:06:35Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18186/fd8c827a6af4217f47017d559ad90e015afade12?t=1497107195',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18212,
#   'title': '12 июня',
#   'color': '00aee0',
#   'createdAt': '2017-06-11T16:48:04Z',
#   'updatedAt': '2017-06-11T16:48:04Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 4,
#   'totalAnsweredQuestions': 3,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18212/ef702cfc1331e11399baf298a6eb009a51c71e2b?t=1497199684',
#   'followed': False,
#   'isExpert': False},
#  {'id': 33601,
#   'title': '12 марта',
#   'color': '5aa6cb',
#   'createdAt': '2019-03-12T20:12:32Z',
#   'updatedAt': '2019-03-12T20:12:32Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/33601/9d5d0e5dd0d350e9b6afa7b3be5b39c08684de92?t=1552421552',
#   'followed': False,
#   'isExpert': False},
#  {'id': 26301,
#   'title': '12 недель',
#   'color': '00b5eb',
#   'createdAt': '2018-04-21T17:34:43Z',
#   'updatedAt': '2018-04-21T17:34:43Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/26301/75d0517af21cde52759bb1b4968603e9f358d5fc?t=1524332083',
#   'followed': False,
#   'isExpert': False},
#  {'id': 25826,
#   'title': '12 стульев',
#   'color': '4ca4e8',
#   'createdAt': '2018-03-29T06:03:21Z',
#   'updatedAt': '2018-03-29T06:03:21Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 2,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/25826/07390f39af58c87ac39b1a87452ae7d25ec56acb?t=1522303401',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18574,
#   'title': '13',
#   'color': '00b29f',
#   'createdAt': '2017-06-22T09:18:42Z',
#   'updatedAt': '2017-06-22T09:18:42Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18574/635518c5c93edf25884494ee8efc6fb9f29df219?t=1498123122',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18357,
#   'title': '13 причин',
#   'color': 'd7869b',
#   'createdAt': '2017-06-16T05:45:53Z',
#   'updatedAt': '2017-06-16T05:45:53Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18357/48bc91f25793f062e12fbece027091410e32b4ab?t=1497591953',
#   'followed': False,
#   'isExpert': False},
#  {'id': 23599,
#   'title': '13причинпочему',
#   'color': '2fb186',
#   'createdAt': '2017-12-20T21:18:51Z',
#   'updatedAt': '2017-12-20T21:18:51Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/23599/c688accad367c088bc907d856f9a7fffd1a98a30?t=1513804731',
#   'followed': False,
#   'isExpert': False},
#  {'id': 27405,
#   'title': '13 причин почему',
#   'color': 'db886f',
#   'createdAt': '2018-06-18T08:20:34Z',
#   'updatedAt': '2018-06-18T08:20:34Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/27405/37fd64996729988f10af0457ed96c13edd660df6?t=1529310034',
#   'followed': False,
#   'isExpert': False},
#  {'id': 8498,
#   'title': '14',
#   'color': '43b07a',
#   'createdAt': '2016-08-21T17:10:25Z',
#   'updatedAt': '2016-08-21T17:10:25Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 4,
#   'totalFollowers': 15,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/8498/7820566b4723d1c1b388e164c2808f01c9c1055b?t=1471799425',
#   'followed': False,
#   'isExpert': False},
#  {'id': 19960,
#   'title': '140 bpm',
#   'color': '74ab6a',
#   'createdAt': '2017-08-07T23:30:03Z',
#   'updatedAt': '2017-08-07T23:30:03Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/19960/e34ffe471ae6fe0d118a1216a20542b4c392726c?t=1502148603',
#   'followed': False,
#   'isExpert': False},
#  {'id': 20171,
#   'title': '140BPm',
#   'color': 'e77aad',
#   'createdAt': '2017-08-15T18:51:11Z',
#   'updatedAt': '2017-08-15T18:51:11Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/20171/13620bbbd46c7d8036b3fcb5c149321197ed22ee?t=1502823071',
#   'followed': False,
#   'isExpert': False},
#  {'id': 4987,
#   'title': '140 символов',
#   'color': 'a298bf',
#   'createdAt': '2016-05-02T13:18:15Z',
#   'updatedAt': '2016-05-02T13:18:15Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 10,
#   'totalFollowers': 114,
#   'totalQuestions': 8,
#   'totalAnsweredQuestions': 3,
#   'totalUnansweredQuestions': 5,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/4987/792979b160920e02e6ef9aa1bb1b4d9462ecb68c?t=1462195095',
#   'followed': False,
#   'isExpert': False},
#  {'id': 10926,
#   'title': '14 лет',
#   'color': 'cd8f6a',
#   'createdAt': '2016-11-08T14:20:00Z',
#   'updatedAt': '2016-11-08T14:20:00Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 9,
#   'totalFollowers': 20,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 3,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/10926/c59d9131b42f462a346a8019b95d3efc75273e08?t=1478614800',
#   'followed': False,
#   'isExpert': False},
#  {'id': 32021,
#   'title': '1—4% против 11%',
#   'color': '5fa9ad',
#   'createdAt': '2019-01-09T04:56:23Z',
#   'updatedAt': '2019-01-09T04:56:23Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/32021/5e468381d3db4708017ce9c305bd9ce15fc86931?t=1547009783',
#   'followed': False,
#   'isExpert': False},
#  {'id': 2276,
#   'title': '14 ФЕВРАЛЯ',
#   'color': 'a89f54',
#   'createdAt': '2016-02-09T08:30:43Z',
#   'updatedAt': '2016-02-09T08:30:43Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 45,
#   'totalFollowers': 181,
#   'totalQuestions': 7,
#   'totalAnsweredQuestions': 4,
#   'totalUnansweredQuestions': 3,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/2276/4eb19c6bb7ad8a7c95c4824cbdc914449c74d366?t=1455006643',
#   'followed': False,
#   'isExpert': False},
#  {'id': 14774,
#   'title': '15',
#   'color': 'ec7a91',
#   'createdAt': '2017-02-25T14:09:17Z',
#   'updatedAt': '2017-02-25T14:09:17Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 1,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/14774/4fd10ee83b051620bb64019abfb429b5d12f9672?t=1488031757',
#   'followed': False,
#   'isExpert': False},
#  {'id': 7903,
#   'title': '15 ЛЕТ',
#   'color': '7ca69d',
#   'createdAt': '2016-08-01T09:13:24Z',
#   'updatedAt': '2016-08-01T09:13:24Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 21,
#   'totalFollowers': 84,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/7903/8ceb00cab2b85027b7fa64ea9220fbf0d580ac29?t=1470042804',
#   'followed': False,
#   'isExpert': False},
#  {'id': 2591,
#   'title': '16',
#   'color': '00b3ce',
#   'createdAt': '2016-02-21T17:49:14Z',
#   'updatedAt': '2016-02-21T17:49:14Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 10,
#   'totalFollowers': 25,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/2591/6bbf2980fa61326b606e1db7e5d8afc3cfe67bcd?t=1456076954',
#   'followed': False,
#   'isExpert': False},
#  {'id': 28787,
#   'title': '169см',
#   'color': '73a897',
#   'createdAt': '2018-08-26T17:37:34Z',
#   'updatedAt': '2018-08-26T17:37:34Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/28787/259401feb376db4a1a956ab7dfede5fb704ee66a?t=1535305054',
#   'followed': False,
#   'isExpert': False},
#  {'id': 30135,
#   'title': '16 бит тому назад',
#   'color': 'cf8d7b',
#   'createdAt': '2018-10-31T11:21:36Z',
#   'updatedAt': '2018-10-31T11:21:36Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/30135/509d2c1cfdd4f699fe17c85cea155ef484d01002?t=1540984896',
#   'followed': False,
#   'isExpert': False},
#  {'id': 25538,
#   'title': '16 лет',
#   'color': '00b4d0',
#   'createdAt': '2018-03-13T22:40:14Z',
#   'updatedAt': '2018-03-13T22:40:14Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 2,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/25538/2bc8edd3a2f8c84fab01cb4a7b6fb6e1cae6759e?t=1520980814',
#   'followed': False,
#   'isExpert': False},
#  {'id': 8307,
#   'title': '1703',
#   'color': 'e47bb0',
#   'createdAt': '2016-08-13T20:31:24Z',
#   'updatedAt': '2016-08-13T20:31:24Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 8,
#   'totalFollowers': 55,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 2,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/8307/190b335cbfaadeaf7b4c92a5886c6b38d2fd532d?t=1471120284',
#   'followed': False,
#   'isExpert': False},
#  {'id': 9880,
#   'title': '1733',
#   'color': 'c89179',
#   'createdAt': '2016-10-08T19:03:49Z',
#   'updatedAt': '2016-10-08T19:03:49Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 1,
#   'totalFollowers': 11,
#   'totalQuestions': 10,
#   'totalAnsweredQuestions': 3,
#   'totalUnansweredQuestions': 7,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/9880/07887e89f444651d24ad6d87b762a938c9f7ac27?t=1475953429',
#   'followed': False,
#   'isExpert': False},
#  {'id': 9881,
#   'title': '1733+323',
#   'color': '749ee3',
#   'createdAt': '2016-10-08T19:14:28Z',
#   'updatedAt': '2016-10-08T19:14:28Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 9,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/9881/067d46477e03c036e804f1dcf724fde689a5d637?t=1475954068',
#   'followed': False,
#   'isExpert': False},
#  {'id': 1857,
#   'title': '18',
#   'color': 'd37fd7',
#   'createdAt': '2016-01-25T16:08:23Z',
#   'updatedAt': '2016-01-25T16:08:23Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 27,
#   'totalFollowers': 177,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 2,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/1857/a8f22c8205483c4e0cd81ad64ccfbe5aaf98080b?t=1453738103',
#   'followed': False,
#   'isExpert': False},
#  {'id': 4348,
#   'title': '+18',
#   'color': 'c19561',
#   'createdAt': '2016-04-12T17:07:01Z',
#   'updatedAt': '2016-04-12T17:07:01Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 88,
#   'totalFollowers': 667,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 2,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/4348/943f0abe3363368e4000a0c6b5d98dc417841005?t=1460480821',
#   'followed': False,
#   'isExpert': False},
#  {'id': 1111,
#   'title': '18+',
#   'color': 'e1828f',
#   'detection': 'секс,18+',
#   'createdAt': '2015-12-27T18:50:52Z',
#   'updatedAt': '2018-02-16T21:20:54Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 1140,
#   'totalFollowers': 19719,
#   'totalQuestions': 453,
#   'totalAnsweredQuestions': 377,
#   'totalUnansweredQuestions': 76,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/1111/3e046cb074fa0e39da17020c0247a16204f6fa9f?t=1518816054',
#   'followed': False,
#   'isExpert': False},
#  {'id': 30955,
#   'title': '1888 г',
#   'color': 'cc86c2',
#   'createdAt': '2018-12-01T19:57:26Z',
#   'updatedAt': '2018-12-01T19:57:26Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/30955/b3952af58f9ac2e7aa2414ae456fb2d438f1dbaa?t=1543694246',
#   'followed': False,
#   'isExpert': False},
#  {'id': 18180,
#   'title': '18 лет',
#   'color': 'c89448',
#   'createdAt': '2017-06-10T09:00:25Z',
#   'updatedAt': '2017-06-10T09:00:25Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 12,
#   'totalAnsweredQuestions': 9,
#   'totalUnansweredQuestions': 3,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/18180/85bffc3e7abb466bf0e83589bcd2f2db20bdc59a?t=1497085225',
#   'followed': False,
#   'isExpert': False},
#  {'id': 5565,
#   'title': '18-летие',
#   'color': 'c97ff0',
#   'createdAt': '2016-05-20T10:36:30Z',
#   'updatedAt': '2016-05-20T10:36:30Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 46,
#   'totalFollowers': 211,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 2,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/5565/6c9d96a40aea1d3c31ebd4a00ba8c6e4c5d96bc1?t=1463740590',
#   'followed': False,
#   'isExpert': False},
#  {'id': 8688,
#   'title': '18сентября',
#   'color': '62af43',
#   'createdAt': '2016-08-28T01:03:07Z',
#   'updatedAt': '2016-08-28T01:03:07Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 1,
#   'totalFollowers': 15,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/8688/2b1889e7040033afe9d16c1ca3f58394b9769f76?t=1472346187',
#   'followed': False,
#   'isExpert': False},
#  {'id': 25075,
#   'title': '1917 год',
#   'color': 'a3a063',
#   'createdAt': '2018-02-20T14:41:51Z',
#   'updatedAt': '2018-02-20T14:41:51Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 6,
#   'totalAnsweredQuestions': 3,
#   'totalUnansweredQuestions': 3,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/25075/3197b40278f666e6a5b23e9697a764eebf4a40b1?t=1519137711',
#   'followed': False,
#   'isExpert': False},
#  {'id': 27854,
#   'title': '1920',
#   'color': '989bbd',
#   'createdAt': '2018-07-04T16:51:38Z',
#   'updatedAt': '2018-07-04T16:51:38Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/27854/ec22de7f986f04215636a0c24ee9047e18e939ee?t=1530723098',
#   'followed': False,
#   'isExpert': False},
#  {'id': 33195,
#   'title': '1941',
#   'color': '44b170',
#   'createdAt': '2019-02-17T19:36:29Z',
#   'updatedAt': '2019-02-17T19:36:29Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/33195/feff726b6154a7f3a01ee8bef58c412b2bc7c9e1?t=1550432189',
#   'followed': False,
#   'isExpert': False},
#  {'id': 26655,
#   'title': '1944',
#   'color': '00b1f0',
#   'createdAt': '2018-05-11T17:05:21Z',
#   'updatedAt': '2018-05-11T17:05:21Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/26655/0c43f271ac6ed8cc29f7842d9d818352040455a6?t=1526058321',
#   'followed': False,
#   'isExpert': False},
#  {'id': 15836,
#   'title': '1950',
#   'color': 'ce88ac',
#   'createdAt': '2017-03-29T06:05:26Z',
#   'updatedAt': '2017-03-29T06:05:26Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 6,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/15836/162910ff2749a86c37cfa16022df4aebfdf7c36a?t=1490767526',
#   'followed': False,
#   'isExpert': False},
#  {'id': 30560,
#   'title': '1950-е',
#   'color': '00b2a8',
#   'createdAt': '2018-11-17T21:21:07Z',
#   'updatedAt': '2018-11-17T21:21:07Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/30560/4563ed87dc76e9f4c98aefc36d8774bdb4899ea4?t=1542489667',
#   'followed': False,
#   'isExpert': False},
#  {'id': 6403,
#   'title': '1950ЫЕ',
#   'color': 'ae9c60',
#   'createdAt': '2016-06-09T20:32:08Z',
#   'updatedAt': '2016-06-09T20:32:08Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 6,
#   'totalFollowers': 153,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/6403/308f8436501a42c25bf66af4c23350d2894d4e88?t=1465504328',
#   'followed': False,
#   'isExpert': False},
#  {'id': 30582,
#   'title': '1953',
#   'color': '49ae90',
#   'createdAt': '2018-11-18T19:08:00Z',
#   'updatedAt': '2018-11-18T19:08:00Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
# ...
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/32229/e25d36a61ca3979d31fcce7b22902fc26b6e2a34?t=1547616646',
#   'followed': False,
#   'isExpert': False},
#  {'id': 29974,
#   'title': 'E-ink',
#   'color': '00b4e2',
#   'createdAt': '2018-10-24T08:32:37Z',
#   'updatedAt': '2018-10-24T08:32:37Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 3,
#   'totalAnsweredQuestions': 2,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/29974/44f4818d09b112eec62fcf1d166ace3ad7db8ff4?t=1540369957',
#   'followed': False,
#   'isExpert': False},
#  {'id': 16696,
#   'title': 'EJEN',
#   'color': '6fa3c9',
#   'createdAt': '2017-04-23T19:39:51Z',
#   'updatedAt': '2017-04-23T19:39:51Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/16696/c611a043e31e4a88143cd59bf7a3267bb59f3c4b?t=1492976391',
#   'followed': False,
#   'isExpert': False},
#  {'id': 28126,
#   'title': 'Ekaterina Gorbacheva',
#   'color': '70a6b0',
#   'createdAt': '2018-07-17T13:38:21Z',
#   'updatedAt': '2018-07-17T13:38:21Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/28126/aa02ef692dd9e29018432f32c9bd17ccc626fe2d?t=1531834701',
#   'followed': False,
#   'isExpert': False},
#  {'id': 23389,
#   'title': 'Ekaterina Proskuryakova',
#   'color': 'd77fcb',
#   'createdAt': '2017-12-12T20:08:46Z',
#   'updatedAt': '2017-12-12T20:08:46Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 2,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/23389/1e0ab1dd0a2b7a78592382d6316b77f1e90bdf2a?t=1513109326',
#   'followed': False,
#   'isExpert': False},
#  {'id': 3170,
#   'title': 'EL CAPITAN',
#   'color': 'ac9c74',
#   'createdAt': '2016-03-14T09:05:29Z',
#   'updatedAt': '2016-03-14T09:05:29Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 5,
#   'totalFollowers': 38,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/3170/c6aac435acf4427b0b7eb5c043299b6e83e1ddb9?t=1457946329',
#   'followed': False,
#   'isExpert': False},
#  {'id': 15557,
#   'title': 'ELECTRONIC',
#   'color': 'f5767a',
#   'createdAt': '2017-03-21T12:59:10Z',
#   'updatedAt': '2017-03-21T12:59:10Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/15557/42fdf5ff7bf71ebdad605d93d48be0329c44d770?t=1490101150',
#   'followed': False,
#   'isExpert': False},
#  {'id': 5968,
#   'title': 'Electronic serial number',
#   'color': 'cf7fe2',
#   'createdAt': '2016-05-30T12:21:54Z',
#   'updatedAt': '2016-05-30T12:21:54Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 13,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/5968/6b4cd7c842db704c3a1cae84ce3e0dfc08105f80?t=1464610914',
#   'followed': False,
#   'isExpert': False},
#  {'id': 29347,
#   'title': 'Elementaree.ru',
#   'color': '35adb3',
#   'companyId': 547,
#   'createdAt': '2018-09-26T14:39:19Z',
#   'updatedAt': '2018-10-01T08:37:08Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 1,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'company': {'id': 547,
#    'topicId': 29347,
#    'active': True,
#    'description': 'Конструктор еды Elementaree. Привезем нарезанные продукты и пошаговые рецепты прямо к холодильнику',
#    'logoId': 776549,
#    'coverId': 776561,
#    'aboutQml': '',
#    'totalAccounts': 1,
#    'createdAt': '2018-09-26T14:40:01Z',
#    'updatedAt': '2018-09-26T14:40:01Z',
#    'activatedAt': '2018-09-26T14:40:01Z',
#    'title': 'Elementaree.ru',
#    'logo': {'id': 776549,
#     'accountId': 417450,
#     'url': 'https://thequestion.s3.eu-central-1.amazonaws.com/450/776548-d1d7dce3.jpeg',
#     'size': 29157,
#     'createdAt': '2018-10-01T08:50:29Z',
#     'imageUrl': 'https://media.thequestion.ru/image/1280x640/a18881714cffe625f9b7220e2639f724dcf3cf7b?url=https%3A%2F%2Fthequestion.s3.eu-central-1.amazonaws.com%2F450%2F776548-d1d7dce3.jpeg',
#     'thumbnailUrl': 'https://media.thequestion.ru/image/250x250/a4477b565651809f5106a5fbb28ce52f8ba8aa44?url=https%3A%2F%2Fthequestion.s3.eu-central-1.amazonaws.com%2F450%2F776548-d1d7dce3.jpeg',
#     'width': 241,
#     'height': 228},
#    'cover': {'id': 776561,
#     'accountId': 417450,
#     'url': 'https://thequestion.s3.eu-central-1.amazonaws.com/450/776560-4f857790.jpeg',
#     'size': 266269,
#     'createdAt': '2018-10-01T08:55:18Z',
#     'imageUrl': 'https://media.thequestion.ru/image/1280x640/84d395a562d55fb4908183e71b93fffb31dbaeb4?url=https%3A%2F%2Fthequestion.s3.eu-central-1.amazonaws.com%2F450%2F776560-4f857790.jpeg',
#     'thumbnailUrl': 'https://media.thequestion.ru/image/250x250/831afe4dac75ee65c2a20c70fc58740247b78844?url=https%3A%2F%2Fthequestion.s3.eu-central-1.amazonaws.com%2F450%2F776560-4f857790.jpeg',
#     'width': 1680,
#     'height': 1103},
#    'permission': {'member': False, 'admin': False}},
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/29347/b8edfc8dd2f48e7754417da2dab6ab28495278a1?t=1538383028',
#   'followed': False,
#   'isExpert': False},
#  {'id': 25204,
#   'title': 'Elena Vigovskaya',
#   'color': '80a2b2',
#   'createdAt': '2018-02-25T18:24:11Z',
#   'updatedAt': '2018-02-25T18:24:11Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/25204/807eea9e0e8d1c856fb077570c1c6489b6ffbe7a?t=1519583051',
#   'followed': False,
#   'isExpert': False},
#  {'id': 30477,
#   'title': 'Elizaveta Kharlova',
#   'color': 'ce9148',
#   'createdAt': '2018-11-14T12:27:00Z',
#   'updatedAt': '2018-11-14T12:27:00Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/30477/c83d038872a0ac69f5a851b1f2b3c8cc9f256c5e?t=1542198420',
#   'followed': False,
#   'isExpert': False},
#  {'id': 23532,
#   'title': 'Elizaveta Osetinskaya',
#   'color': 'c48cb5',
#   'createdAt': '2017-12-19T07:51:42Z',
#   'updatedAt': '2017-12-19T07:51:42Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 28,
#   'totalAnsweredQuestions': 16,
#   'totalUnansweredQuestions': 12,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/23532/c9676437bcb0bb48f4af42e9ba4e143fc24ae9f7?t=1513669902',
#   'followed': False,
#   'isExpert': False},
#  {'id': 26731,
#   'title': 'Elnur Rosso',
#   'color': '00b1eb',
#   'createdAt': '2018-05-15T18:59:09Z',
#   'updatedAt': '2018-05-15T18:59:09Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/26731/751ec77954c815c55b8a39585aeeb5ba9ab62425?t=1526410749',
#   'followed': False,
#   'isExpert': False},
#  {'id': 29471,
#   'title': 'elvira t',
#   'color': '45ada7',
#   'createdAt': '2018-10-03T11:29:09Z',
#   'updatedAt': '2018-10-03T11:29:09Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/29471/d4d0cf542842bac943d4006590d158eb99660f51?t=1538566149',
#   'followed': False,
#   'isExpert': False},
#  {'id': 7599,
#   'title': 'e-mail',
#   'color': '78aa64',
#   'createdAt': '2016-07-20T22:20:59Z',
#   'updatedAt': '2016-07-20T22:20:59Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 3,
#   'totalFollowers': 27,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/7599/927d90d76e92a5ae005bb9b7f528974f74b9f9fe?t=1469053259',
#   'followed': False,
#   'isExpert': False},
#  {'id': 21547,
#   'title': 'Emi Estevesz',
#   'color': '00abf4',
#   'createdAt': '2017-10-04T17:08:52Z',
#   'updatedAt': '2017-10-04T17:08:52Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/21547/53870250ee7929913451e3a0a2f77f8c33253433?t=1507136932',
#   'followed': False,
#   'isExpert': False},
#  {'id': 6959,
#   'title': 'EMINEM',
#   'color': 'b89957',
#   'createdAt': '2016-06-28T11:32:25Z',
#   'updatedAt': '2016-06-28T11:32:25Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 9,
#   'totalFollowers': 72,
#   'totalQuestions': 6,
#   'totalAnsweredQuestions': 5,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/6959/1a6522f8da55cb8873eda597e7ae93e3ceb0063c?t=1467113545',
#   'followed': False,
#   'isExpert': False},
#  {'id': 22864,
#   'title': 'emma watson',
#   'color': '00b0d9',
#   'createdAt': '2017-11-23T09:35:42Z',
#   'updatedAt': '2017-11-23T09:35:42Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 0,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/22864/3c520f0d6ada5d2e7901a8085aee49a61f94853b?t=1511429742',
#   'followed': False,
#   'isExpert': False},
#  {'id': 14061,
#   'title': 'emoji',
#   'color': 'b09a7a',
#   'createdAt': '2017-02-07T18:54:35Z',
#   'updatedAt': '2017-02-07T18:54:35Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 8,
#   'totalQuestions': 2,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 2,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/14061/f185871a6888fb2111f69e81b584840b96029a96?t=1486493675',
#   'followed': False,
#   'isExpert': False},
#  {'id': 27401,
#   'title': 'Encore',
#   'color': '9d9da1',
#   'createdAt': '2018-06-18T03:20:17Z',
#   'updatedAt': '2018-06-18T03:20:17Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/27401/59f8f8fdf8f67797b965acdceb77215c656932a7?t=1529292017',
#   'followed': False,
#   'isExpert': False},
#  {'id': 33633,
#   'title': 'endgame',
#   'color': 'cf904c',
#   'createdAt': '2019-03-14T13:58:10Z',
#   'updatedAt': '2019-03-14T13:58:10Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/33633/852193c1918f8bb0f70ea37dff3a3e14b4a46746?t=1552571890',
#   'followed': False,
#   'isExpert': False},
#  {'id': 24049,
#   'title': 'ENDING',
#   'color': 'ba939e',
#   'createdAt': '2018-01-09T20:36:16Z',
#   'updatedAt': '2018-01-09T20:36:16Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/24049/c0af20e081752e5532e6bbfda95be035801667b4?t=1515530176',
#   'followed': False,
#   'isExpert': False},
#  {'id': 27397,
#   'title': 'endurance',
#   'color': 'c09295',
#   'createdAt': '2018-06-17T06:29:15Z',
#   'updatedAt': '2018-06-17T06:29:15Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 1,
#   'totalUnansweredQuestions': 0,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/27397/cd543b766b50b434b6cedb6a87c6a165c8225fa4?t=1529216955',
#   'followed': False,
#   'isExpert': False},
#  {'id': 29456,
#   'title': 'energy',
#   'color': '8da74d',
#   'createdAt': '2018-10-03T01:26:39Z',
#   'updatedAt': '2018-10-03T01:26:39Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/29456/e05340d7ba5b20161d4d7d1a9f4371f703b78385?t=1538529999',
#   'followed': False,
#   'isExpert': False},
#  {'id': 28910,
#   'title': 'englis',
#   'color': 'ac989d',
#   'createdAt': '2018-09-04T12:20:24Z',
#   'updatedAt': '2018-09-04T12:20:24Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 0,
#   'totalFollowers': 0,
#   'totalQuestions': 1,
#   'totalAnsweredQuestions': 0,
#   'totalUnansweredQuestions': 1,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/28910/c0cba683b258b595ec1c0009aa0e054c01737be1?t=1536063624',
#   'followed': False,
#   'isExpert': False},
#  {'id': 8154,
#   'title': 'english',
#   'color': 'd18e65',
#   'createdAt': '2016-08-08T09:13:27Z',
#   'updatedAt': '2016-08-08T09:13:27Z',
#   'deleted': False,
#   'lang': 'ru',
#   'totalExperts': 29,
#   'totalFollowers': 385,
#   'totalQuestions': 38,
#   'totalAnsweredQuestions': 26,
#   'totalUnansweredQuestions': 12,
#   'totalDraftComps': 0,
#   'totalPublicComps': 0,
#   'main': False,
#   'parentTopicIds': [],
#   'cardUrl': 'https://media.thequestion.ru/cards/topic/8154/9bd7ffd44e291a625959505af1e85ae3e0a7491c?t=1470647607',
#   'followed': False,
#   'isExpert': False},
#  ...]

# %%
top_tags = []

for res in result:
    if res.get('totalQuestions') > 1000:
        top_tags.append(res['title'])

# %%
top_tags
# Out:
# ['Apple',
#  'IT (информационные технологии)',
#  'TheQuestion',
#  'YouTube',
#  'Авиация',
#  'Авто',
#  'Актуально',
#  'Алкоголь',
#  'Анатомия',
#  'Английский язык',
#  'Армия',
#  'Архитектура',
#  'Банки',
#  'Безопасность',
#  'Бизнес',
#  'Биология',
#  'Болезнь',
#  'Будущее',
#  'Быт',
#  'Видео',
#  'ВКонтакте',
#  'Владимир Путин',
#  'Власть',
#  'Внешность',
#  'Война',
#  'Волосы',
#  'Вопрос',
#  'ВУЗ',
#  'Выбор профессии',
#  'Выборы',
#  'Высшее образование',
#  'Гаджеты',
#  'География',
#  'Главная страница',
#  'Города',
#  'Государство',
#  'Девушки',
#  'Деньги',
#  'Дети',
#  'Детский вопрос',
#  'Дизайн',
#  'Дискриминация',
#  'Дом',
#  'Дружба',
#  'Европа',
#  'ЕГЭ',
#  'Еда',
#  'Женщины',
#  'Животные',
#  'Жизнь',
#  'Журналистика',
#  'Закон',
#  'Зачем я это узнал?',
#  'Зашкваршн',
#  'здоровое питание',
#  'Здоровье',
#  'Знаменитости',
#  'Игры',
#  'Иностранные языки',
#  'Интервью',
#  'Интересное',
#  'Интернет',
#  'Искусство',
#  'Искусство и культура',
#  'Ислам',
#  'История',
#  'Как это работает?',
#  'Карьера',
#  'Кафе и рестораны',
#  'Кино',
#  'Классная история',
#  'Книги',
#  'Компьютерные игры',
#  'Компьютеры',
#  'Космос',
#  'Красота',
#  'Криминал',
#  'Культура',
#  'Курение',
#  'Лайфхак',
#  'ЛГБТ',
#  'Лингвистика',
#  'Литература',
#  'Личность',
#  'Личный опыт',
#  'Любовь',
#  'Маркетинг',
#  'Математика',
#  'Медиа',
#  'Медицина',
#  'Мемы',
#  'мероприятия',
#  'Метрополитен',
#  'Мифы',
#  'Мода',
#  'Мозг',
#  'Москва',
#  'Мужчины',
#  'Музыка',
#  'Наркотики',
#  'Наука',
#  'Новости',
#  'Образование',
#  'Обучение',
#  'Общение',
#  'Общество',
#  'Одежда',
#  'Организм',
#  'Отношения',
#  'Питание',
#  'Политика',
#  'Поэзия',
#  'Природа',
#  'Программирование',
#  'Профессия',
#  'Прямая линия',
#  'Психиатрия',
#  'Психика',
#  'Психология',
#  'Психотерапия',
#  'Путешествия',
#  'Работа',
#  'Реклама',
#  'Религия',
#  'Родители',
#  'Россия',
#  'Русский язык',
#  'Рэп',
#  'Саморазвитие',
#  'Самосовершенствование',
#  'Санкт-Петербург',
#  'Сверхъестественное',
#  'Секс',
#  'Семья',
#  'Сериалы',
#  'Смерть',
#  'смешное',
#  'СМИ',
#  'Сон',
#  'Социальные сети',
#  'Социология',
#  'Социум',
#  'Спорт',
#  'СССР',
#  'Стиль',
#  'Страны',
#  'США',
#  'Телевидение',
#  'Тело',
#  'Темы нет',
#  'Теория науки',
#  'Терроризм',
#  'Техника',
#  'Технологии',
#  'Транспорт',
#  'Туризм',
#  'Украина',
#  'Университет',
#  'Учеба',
#  'Феминизм',
#  'Физика',
#  'Физиология',
#  'Философия',
#  'Финансы',
#  'Фотография',
#  'Футбол',
#  'Химия',
#  'Христианство',
#  'Человек',
#  'Что будет, если',
#  'Что почитать?',
#  'Чувства',
#  'Школа',
#  'Шоппинг',
#  'Экология',
#  'Экономика',
#  'Этикет',
#  'Юмор',
#  'Юриспруденция',
#  'Язык']
